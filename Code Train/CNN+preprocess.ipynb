# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

def preprocess_image(img):
    img = img.astype(np.uint8)
    img = cv2.resize(img, (224,224))

    denoise = cv2.bilateralFilter(
        img,
        5,
        50,
        50
    )

    lab = cv2.cvtColor(denoise, cv2.COLOR_RGB2LAB)

    l, a, b = cv2.split(lab)

    clahe = cv2.createCLAHE(
        clipLimit=2.0,
        tileGridSize=(8,8)
    )

    l = clahe.apply(l)

    lab = cv2.merge((l,a,b))

    img = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)
    img = img.astype(np.float32)
    return img
    

train_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/train"
test_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/test"
val_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/val"


print("Train exists:", os.path.exists(train_dir))
print("Val exists:", os.path.exists(val_dir))
print("Test exists:", os.path.exists(test_dir))

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image,
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image,
    rescale=1./255
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image,
    rescale=1./255
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)


num_classes = train_generator.num_classes
print(f"Số lượng classes: {num_classes}")


inputs = Input(shape=(224,224,3))
x = inputs

x = Conv2D(64, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(64, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D((2,2))(x)
x = Dropout(0.2)(x)

x = Conv2D(128, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(128, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D((2,2))(x)
x = Dropout(0.25)(x)

x = Conv2D(256, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(256, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(256, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D((2,2))(x)
x = Dropout(0.3)(x)

x = Conv2D(512, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(512, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D((2,2))(x)
x = Dropout(0.35)(x)

x = GlobalAveragePooling2D()(x)

x = Dense(
    512,
    activation='relu',
    kernel_regularizer=l2(1e-4)
)(x)

x = BatchNormalization()(x)
x = Dropout(0.5)(x)

outputs = Dense(num_classes, activation='softmax')(x)

model = Model(inputs, outputs)

model.summary()

model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(train_generator, epochs=50, validation_data=val_generator)

loss, acc = model.evaluate(test_generator)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {acc:.4f}")

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Phase 1: Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Phase 1: Loss')
plt.legend()
plt.show()

y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

y_true = test_generator.classes
class_names = list(train_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, xticklabels=class_names, yticklabels=class_names, cmap="Blues", fmt="d")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
# 2026-05-16 04:47:14.745130: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778906834.939597      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778906834.995721      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778906835.457469      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778906835.457508      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778906835.457510      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778906835.457513      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Train exists: True
# Val exists: True
# Test exists: True
# Found 11338 images belonging to 4 classes.
# Found 2431 images belonging to 4 classes.
# Found 2432 images belonging to 4 classes.
# Số lượng classes: 4
# I0000 00:00:1778906868.117294      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1778906868.123194      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 64)   │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 128)  │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 128)  │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 56, 56, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 256)    │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 56, 56, 256)    │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 28, 28, 512)    │     1,179,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 512)    │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,548,740 (21.17 MB)
#  Trainable params: 5,543,364 (21.15 MB)
#  Non-trainable params: 5,376 (21.00 KB)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778906876.589571      92 service.cc:152] XLA service 0x7a1570003910 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778906876.589622      92 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778906876.589629      92 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778906877.669780      92 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-05-16 04:48:15.494404: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:48:15.691030: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:48:17.245036: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:48:17.417536: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:48:21.217944: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:48:21.555257: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:48:21.703191: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.15 = (f32[32,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,224,224]{3,2,1,0} %bitcast.22646, f32[64,64,3,3]{3,2,1,0} %bitcast.20350), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_1_2/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-05-16 04:48:21.888353: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:48:21.908616: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.205645269s
# Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.15 = (f32[32,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,224,224]{3,2,1,0} %bitcast.22646, f32[64,64,3,3]{3,2,1,0} %bitcast.20350), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_1_2/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1778906917.231237      92 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  11/355 ━━━━━━━━━━━━━━━━━━━━ 2:56 513ms/step - accuracy: 0.2492 - loss: 2.1072
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 189/355 ━━━━━━━━━━━━━━━━━━━━ 1:25 513ms/step - accuracy: 0.3416 - loss: 1.8239
# 2026-05-16 04:50:24.104481: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:50:24.293254: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:50:25.162673: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:50:25.328170: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:50:26.827296: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 04:50:27.137994: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 306s 733ms/step - accuracy: 0.3608 - loss: 1.7569 - val_accuracy: 0.2415 - val_loss: 1.5571
# Epoch 2/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 171s 481ms/step - accuracy: 0.4485 - loss: 1.4638 - val_accuracy: 0.3554 - val_loss: 1.4896
# Epoch 3/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 483ms/step - accuracy: 0.4934 - loss: 1.3789 - val_accuracy: 0.4517 - val_loss: 1.3405
# Epoch 4/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 173s 486ms/step - accuracy: 0.5133 - loss: 1.3037 - val_accuracy: 0.4056 - val_loss: 1.5438
# Epoch 5/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 484ms/step - accuracy: 0.5425 - loss: 1.2191 - val_accuracy: 0.5829 - val_loss: 1.0764
# Epoch 6/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 171s 482ms/step - accuracy: 0.5830 - loss: 1.1325 - val_accuracy: 0.5339 - val_loss: 1.1698
# Epoch 7/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 173s 487ms/step - accuracy: 0.5918 - loss: 1.0983 - val_accuracy: 0.5224 - val_loss: 1.2061
# Epoch 8/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 171s 482ms/step - accuracy: 0.6180 - loss: 1.0450 - val_accuracy: 0.6409 - val_loss: 1.0237
# Epoch 9/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 175s 491ms/step - accuracy: 0.6319 - loss: 0.9909 - val_accuracy: 0.4858 - val_loss: 2.3630
# Epoch 10/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 485ms/step - accuracy: 0.6464 - loss: 0.9554 - val_accuracy: 0.4903 - val_loss: 1.4572
# Epoch 11/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 171s 482ms/step - accuracy: 0.6686 - loss: 0.9082 - val_accuracy: 0.6043 - val_loss: 1.1284
# Epoch 12/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 175s 491ms/step - accuracy: 0.6663 - loss: 0.8946 - val_accuracy: 0.5611 - val_loss: 1.5706
# Epoch 13/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 483ms/step - accuracy: 0.6796 - loss: 0.8636 - val_accuracy: 0.6026 - val_loss: 1.0466
# Epoch 14/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 173s 487ms/step - accuracy: 0.6921 - loss: 0.8267 - val_accuracy: 0.6339 - val_loss: 1.0661
# Epoch 15/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 175s 493ms/step - accuracy: 0.7073 - loss: 0.7927 - val_accuracy: 0.5418 - val_loss: 1.3645
# Epoch 16/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 484ms/step - accuracy: 0.7215 - loss: 0.7637 - val_accuracy: 0.6179 - val_loss: 1.0976
# Epoch 17/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 179s 502ms/step - accuracy: 0.7243 - loss: 0.7429 - val_accuracy: 0.6438 - val_loss: 0.9322
# Epoch 18/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 483ms/step - accuracy: 0.7413 - loss: 0.7216 - val_accuracy: 0.6228 - val_loss: 1.1881
# Epoch 19/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 173s 486ms/step - accuracy: 0.7510 - loss: 0.7043 - val_accuracy: 0.7166 - val_loss: 0.7742
# Epoch 20/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 483ms/step - accuracy: 0.7402 - loss: 0.6973 - val_accuracy: 0.6656 - val_loss: 0.8776
# Epoch 21/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 484ms/step - accuracy: 0.7690 - loss: 0.6448 - val_accuracy: 0.6479 - val_loss: 0.9909
# Epoch 22/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 177s 498ms/step - accuracy: 0.7687 - loss: 0.6439 - val_accuracy: 0.6216 - val_loss: 1.0652
# Epoch 23/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 175s 494ms/step - accuracy: 0.7758 - loss: 0.6278 - val_accuracy: 0.4813 - val_loss: 1.8077
# Epoch 24/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 187s 524ms/step - accuracy: 0.7839 - loss: 0.6080 - val_accuracy: 0.7400 - val_loss: 0.7362
# Epoch 25/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 170s 479ms/step - accuracy: 0.7869 - loss: 0.5963 - val_accuracy: 0.6067 - val_loss: 1.1359
# Epoch 26/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 168s 473ms/step - accuracy: 0.7881 - loss: 0.5875 - val_accuracy: 0.7088 - val_loss: 0.8206
# Epoch 27/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 169s 475ms/step - accuracy: 0.7977 - loss: 0.5590 - val_accuracy: 0.6512 - val_loss: 1.0222
# Epoch 28/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 169s 476ms/step - accuracy: 0.7970 - loss: 0.5672 - val_accuracy: 0.6133 - val_loss: 1.2032
# Epoch 29/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 483ms/step - accuracy: 0.8062 - loss: 0.5539 - val_accuracy: 0.6039 - val_loss: 1.2472
# Epoch 30/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 169s 474ms/step - accuracy: 0.8181 - loss: 0.5128 - val_accuracy: 0.7437 - val_loss: 0.7426
# Epoch 31/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 168s 474ms/step - accuracy: 0.8192 - loss: 0.5067 - val_accuracy: 0.6652 - val_loss: 0.9034
# Epoch 32/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 170s 477ms/step - accuracy: 0.8272 - loss: 0.4880 - val_accuracy: 0.7437 - val_loss: 0.7797
# Epoch 33/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 170s 477ms/step - accuracy: 0.8343 - loss: 0.4702 - val_accuracy: 0.7067 - val_loss: 0.8311
# Epoch 34/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 169s 475ms/step - accuracy: 0.8285 - loss: 0.4856 - val_accuracy: 0.5878 - val_loss: 1.6774
# Epoch 35/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 168s 474ms/step - accuracy: 0.8465 - loss: 0.4456 - val_accuracy: 0.7478 - val_loss: 0.7746
# Epoch 36/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 172s 484ms/step - accuracy: 0.8460 - loss: 0.4431 - val_accuracy: 0.7725 - val_loss: 0.6745
# Epoch 37/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 171s 479ms/step - accuracy: 0.8505 - loss: 0.4261 - val_accuracy: 0.7046 - val_loss: 1.0947
# Epoch 38/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 173s 488ms/step - accuracy: 0.8573 - loss: 0.4022 - val_accuracy: 0.6503 - val_loss: 1.2343
# Epoch 39/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 171s 482ms/step - accuracy: 0.8599 - loss: 0.4043 - val_accuracy: 0.7622 - val_loss: 0.7006
# Epoch 40/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 169s 476ms/step - accuracy: 0.8692 - loss: 0.3823 - val_accuracy: 0.5339 - val_loss: 1.9644
# Epoch 41/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 170s 477ms/step - accuracy: 0.8705 - loss: 0.3780 - val_accuracy: 0.7417 - val_loss: 0.8552
# Epoch 42/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 169s 474ms/step - accuracy: 0.8637 - loss: 0.3788 - val_accuracy: 0.7166 - val_loss: 0.9513
# Epoch 43/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 168s 474ms/step - accuracy: 0.8753 - loss: 0.3742 - val_accuracy: 0.6767 - val_loss: 1.1544
# Epoch 44/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 170s 478ms/step - accuracy: 0.8806 - loss: 0.3431 - val_accuracy: 0.7869 - val_loss: 0.6351
# Epoch 45/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 169s 474ms/step - accuracy: 0.8952 - loss: 0.3248 - val_accuracy: 0.5673 - val_loss: 1.7069
# Epoch 46/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 169s 475ms/step - accuracy: 0.8891 - loss: 0.3165 - val_accuracy: 0.7137 - val_loss: 0.9590
# Epoch 47/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 171s 480ms/step - accuracy: 0.8916 - loss: 0.3189 - val_accuracy: 0.7199 - val_loss: 0.9826
# Epoch 48/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 174s 489ms/step - accuracy: 0.8969 - loss: 0.3110 - val_accuracy: 0.7137 - val_loss: 1.0256
# Epoch 49/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 176s 496ms/step - accuracy: 0.8932 - loss: 0.3051 - val_accuracy: 0.6903 - val_loss: 1.1114
# Epoch 50/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 173s 486ms/step - accuracy: 0.9022 - loss: 0.2868 - val_accuracy: 0.7927 - val_loss: 0.6733
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 43s 570ms/step - accuracy: 0.8201 - loss: 0.5626
# Test Loss: 0.6664, Test Accuracy: 0.7874
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 26s 324ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        glass       0.75      0.85      0.80       627
#        metal       0.86      0.74      0.79       569
#        paper       0.87      0.81      0.83       599
#      plastic       0.71      0.75      0.73       637
#
#     accuracy                           0.79      2432
#    macro avg       0.80      0.79      0.79      2432
# weighted avg       0.79      0.79      0.79      2432

# %%
model.save("garbage_classifier_MobileNet.keras")

import json
with open("class_indices.json", "w") as f:
    json.dump(train_generator.class_indices, f)

print("Đã lưu model và class_indices!")
# Out:
# Đã lưu model và class_indices!
