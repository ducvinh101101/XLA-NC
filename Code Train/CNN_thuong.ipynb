# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNet
    

train_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/train"
test_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/test"
val_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/val"

import os

print("Train exists:", os.path.exists(train_dir))
print("Val exists:", os.path.exists(val_dir))
print("Test exists:", os.path.exists(test_dir))

train_datagen = ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_datagen = ImageDataGenerator(
    rescale=1./255
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

test_datagen = ImageDataGenerator(
    rescale=1./255
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)


num_classes = train_generator.num_classes
print(f"Số lượng classes: {num_classes}")

from tensorflow.keras.regularizers import l2

inputs = Input(shape=(224,224,3))
x = inputs

x = Conv2D(64, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(64, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D((2,2))(x)
x = Dropout(0.2)(x)

x = Conv2D(128, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(128, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D((2,2))(x)
x = Dropout(0.25)(x)

x = Conv2D(256, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(256, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(256, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D((2,2))(x)
x = Dropout(0.3)(x)

x = Conv2D(512, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(512, (3,3), padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D((2,2))(x)
x = Dropout(0.35)(x)

x = GlobalAveragePooling2D()(x)

x = Dense(
    512,
    activation='relu',
    kernel_regularizer=l2(1e-4)
)(x)

x = BatchNormalization()(x)
x = Dropout(0.5)(x)

outputs = Dense(num_classes, activation='softmax')(x)

model = Model(inputs, outputs)

model.summary()

model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(train_generator, epochs=50, validation_data=val_generator)

loss, acc = model.evaluate(test_generator)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {acc:.4f}")

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Phase 1: Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Phase 1: Loss')
plt.legend()
plt.show()

y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

y_true = test_generator.classes
class_names = list(train_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, xticklabels=class_names, yticklabels=class_names, cmap="Blues", fmt="d")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
# 2026-05-16 00:26:02.119367: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778891162.525548      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778891162.643729      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778891163.640253      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778891163.640301      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778891163.640304      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778891163.640306      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Train exists: True
# Val exists: True
# Test exists: True
# Found 11338 images belonging to 4 classes.
# Found 2431 images belonging to 4 classes.
# Found 2432 images belonging to 4 classes.
# Số lượng classes: 4
# I0000 00:00:1778891208.408570      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1778891208.414505      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 64)   │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 128)  │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 128)  │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 112, 112, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 56, 56, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 256)    │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 56, 56, 256)    │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 56, 56, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 28, 28, 512)    │     1,179,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 512)    │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 28, 28, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,548,740 (21.17 MB)
#  Trainable params: 5,543,364 (21.15 MB)
#  Non-trainable params: 5,376 (21.00 KB)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778891216.887877      92 service.cc:152] XLA service 0x7910dc002c90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778891216.887916      92 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778891216.887920      92 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778891218.077471      92 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-05-16 00:27:16.110826: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:27:16.304241: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:27:17.946300: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:27:18.117201: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:27:21.685363: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:27:22.026000: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1778891257.165235      92 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   3/355 ━━━━━━━━━━━━━━━━━━━━ 2:17 391ms/step - accuracy: 0.2257 - loss: 2.0535
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 343/355 ━━━━━━━━━━━━━━━━━━━━ 4s 405ms/step - accuracy: 0.3573 - loss: 1.7045
# 2026-05-16 00:30:05.926200: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:30:06.113297: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:30:06.937917: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:30:07.102579: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:30:08.786846: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-16 00:30:09.102141: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 256s 591ms/step - accuracy: 0.3584 - loss: 1.7012 - val_accuracy: 0.2579 - val_loss: 1.7671
# Epoch 2/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.4542 - loss: 1.4414 - val_accuracy: 0.4381 - val_loss: 1.4011
# Epoch 3/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.4673 - loss: 1.3900 - val_accuracy: 0.4529 - val_loss: 1.5590
# Epoch 4/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 461ms/step - accuracy: 0.5208 - loss: 1.2732 - val_accuracy: 0.4323 - val_loss: 1.4017
# Epoch 5/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 165s 463ms/step - accuracy: 0.5454 - loss: 1.2101 - val_accuracy: 0.5265 - val_loss: 1.2590
# Epoch 6/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.5727 - loss: 1.1561 - val_accuracy: 0.5068 - val_loss: 1.4099
# Epoch 7/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.5928 - loss: 1.0896 - val_accuracy: 0.5446 - val_loss: 1.2830
# Epoch 8/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.6144 - loss: 1.0165 - val_accuracy: 0.5899 - val_loss: 1.1633
# Epoch 9/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 459ms/step - accuracy: 0.6236 - loss: 1.0054 - val_accuracy: 0.4545 - val_loss: 1.4461
# Epoch 10/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.6458 - loss: 0.9479 - val_accuracy: 0.6376 - val_loss: 0.9525
# Epoch 11/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.6554 - loss: 0.9255 - val_accuracy: 0.5006 - val_loss: 1.4381
# Epoch 12/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.6742 - loss: 0.8830 - val_accuracy: 0.5993 - val_loss: 1.0615
# Epoch 13/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.6827 - loss: 0.8596 - val_accuracy: 0.6977 - val_loss: 0.8435
# Epoch 14/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 460ms/step - accuracy: 0.6954 - loss: 0.8374 - val_accuracy: 0.6841 - val_loss: 0.9204
# Epoch 15/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 462ms/step - accuracy: 0.7125 - loss: 0.7887 - val_accuracy: 0.6397 - val_loss: 0.9999
# Epoch 16/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 458ms/step - accuracy: 0.7261 - loss: 0.7560 - val_accuracy: 0.6364 - val_loss: 0.9800
# Epoch 17/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 459ms/step - accuracy: 0.7290 - loss: 0.7407 - val_accuracy: 0.5640 - val_loss: 1.5645
# Epoch 18/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.7297 - loss: 0.7283 - val_accuracy: 0.6035 - val_loss: 1.2156
# Epoch 19/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.7470 - loss: 0.7039 - val_accuracy: 0.6816 - val_loss: 0.8798
# Epoch 20/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.7659 - loss: 0.6600 - val_accuracy: 0.7129 - val_loss: 0.7859
# Epoch 21/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 459ms/step - accuracy: 0.7599 - loss: 0.6613 - val_accuracy: 0.7174 - val_loss: 0.7936
# Epoch 22/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 459ms/step - accuracy: 0.7745 - loss: 0.6262 - val_accuracy: 0.7302 - val_loss: 0.7510
# Epoch 23/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.7706 - loss: 0.6212 - val_accuracy: 0.6750 - val_loss: 1.0373
# Epoch 24/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.7937 - loss: 0.5864 - val_accuracy: 0.7647 - val_loss: 0.6874
# Epoch 25/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 460ms/step - accuracy: 0.7886 - loss: 0.5859 - val_accuracy: 0.6948 - val_loss: 0.9986
# Epoch 26/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.7998 - loss: 0.5739 - val_accuracy: 0.6516 - val_loss: 1.0347
# Epoch 27/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 460ms/step - accuracy: 0.7980 - loss: 0.5607 - val_accuracy: 0.7466 - val_loss: 0.6816
# Epoch 28/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 459ms/step - accuracy: 0.8143 - loss: 0.5203 - val_accuracy: 0.6705 - val_loss: 0.8782
# Epoch 29/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 459ms/step - accuracy: 0.8105 - loss: 0.5376 - val_accuracy: 0.7310 - val_loss: 0.7573
# Epoch 30/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 462ms/step - accuracy: 0.8147 - loss: 0.5195 - val_accuracy: 0.6310 - val_loss: 1.1861
# Epoch 31/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.8308 - loss: 0.4932 - val_accuracy: 0.6722 - val_loss: 0.9433
# Epoch 32/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 460ms/step - accuracy: 0.8407 - loss: 0.4650 - val_accuracy: 0.6265 - val_loss: 1.2890
# Epoch 33/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 460ms/step - accuracy: 0.8383 - loss: 0.4647 - val_accuracy: 0.7277 - val_loss: 0.8171
# Epoch 34/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.8386 - loss: 0.4566 - val_accuracy: 0.6837 - val_loss: 0.9844
# Epoch 35/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 460ms/step - accuracy: 0.8383 - loss: 0.4532 - val_accuracy: 0.7598 - val_loss: 0.7019
# Epoch 36/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 460ms/step - accuracy: 0.8496 - loss: 0.4173 - val_accuracy: 0.6717 - val_loss: 1.2372
# Epoch 37/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.8538 - loss: 0.4167 - val_accuracy: 0.6952 - val_loss: 0.9966
# Epoch 38/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 462ms/step - accuracy: 0.8582 - loss: 0.4102 - val_accuracy: 0.7495 - val_loss: 0.8149
# Epoch 39/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.8529 - loss: 0.4081 - val_accuracy: 0.7886 - val_loss: 0.6945
# Epoch 40/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.8667 - loss: 0.3914 - val_accuracy: 0.7330 - val_loss: 0.9067
# Epoch 41/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 460ms/step - accuracy: 0.8672 - loss: 0.3832 - val_accuracy: 0.6438 - val_loss: 1.2286
# Epoch 42/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.8680 - loss: 0.3752 - val_accuracy: 0.6302 - val_loss: 1.5199
# Epoch 43/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.8755 - loss: 0.3649 - val_accuracy: 0.6935 - val_loss: 1.1658
# Epoch 44/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.8818 - loss: 0.3397 - val_accuracy: 0.7495 - val_loss: 0.8326
# Epoch 45/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.8872 - loss: 0.3299 - val_accuracy: 0.7347 - val_loss: 0.9068
# Epoch 46/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 164s 461ms/step - accuracy: 0.8936 - loss: 0.3105 - val_accuracy: 0.7507 - val_loss: 0.8727
# Epoch 47/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 459ms/step - accuracy: 0.8940 - loss: 0.3170 - val_accuracy: 0.7651 - val_loss: 0.8275
# Epoch 48/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.8926 - loss: 0.3095 - val_accuracy: 0.7631 - val_loss: 0.8907
# Epoch 49/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 460ms/step - accuracy: 0.8922 - loss: 0.3170 - val_accuracy: 0.7717 - val_loss: 0.8173
# Epoch 50/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 163s 459ms/step - accuracy: 0.9004 - loss: 0.2902 - val_accuracy: 0.6964 - val_loss: 1.1188
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 29s 381ms/step - accuracy: 0.7194 - loss: 0.9677
# Test Loss: 1.1913, Test Accuracy: 0.6805
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        glass       0.83      0.66      0.73       627
#        metal       0.50      0.96      0.65       569
#        paper       0.92      0.51      0.65       599
#      plastic       0.78      0.61      0.69       637
#
#     accuracy                           0.68      2432
#    macro avg       0.76      0.69      0.68      2432
# weighted avg       0.76      0.68      0.68      2432

# %%
model.save("garbage_classifier_MobileNet.keras")

import json
with open("class_indices.json", "w") as f:
    json.dump(train_generator.class_indices, f)

print("Đã lưu model và class_indices!")
# Out:
# Đã lưu model và class_indices!
