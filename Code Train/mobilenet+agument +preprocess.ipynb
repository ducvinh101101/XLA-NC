# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

train_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/train"
val_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/val"
test_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/test"


def preprocess_image(img):

    img_uint8 = img.astype(np.uint8)

    denoised = cv2.bilateralFilter(
        img_uint8,
        d=3,
        sigmaColor=40,
        sigmaSpace=40
    )

    lab = cv2.cvtColor(denoised, cv2.COLOR_RGB2LAB)

    l, a, b = cv2.split(lab)

    clahe = cv2.createCLAHE(
        clipLimit=1.1,
        tileGridSize=(8,8)
    )

    l_eq = clahe.apply(l)

    lab_eq = cv2.merge((l_eq, a, b))

    contrast_img = cv2.cvtColor(
        lab_eq,
        cv2.COLOR_LAB2RGB
    )


    final_img = contrast_img.astype(np.float32)

    final_img = preprocess_input(final_img)

    return final_img

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,

    zoom_range=0.2,

    shear_range=0.2,

    horizontal_flip=True,

    brightness_range=[0.8, 1.2]
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

base_model = MobileNet(
    include_top=False,
    weights='imagenet',
    input_shape=(224,224,3)
)

for layer in base_model.layers:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)

output = Dense(
    train_generator.num_classes,
    activation='softmax'
)(x)

model = Model(
    inputs=base_model.input,
    outputs=output
)

model.compile(
    optimizer=Adam(1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# early_stop = EarlyStopping(
#     monitor='val_loss',
#     patience=5,
#     restore_best_weights=True
# )

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    verbose=1
)

history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[reduce_lr]
)


loss, acc = model.evaluate(test_generator)

print("Test Accuracy:", acc)

y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(
    test_generator.classes,
    y_pred_classes
)

plt.figure(figsize=(10,8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=train_generator.class_indices.keys(),
    yticklabels=train_generator.class_indices.keys()
)

plt.show()

print(classification_report(
    test_generator.classes,
    y_pred_classes,
    target_names=list(train_generator.class_indices.keys())
))
# Out:
# 2026-05-23 04:57:46.154465: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779512266.382519      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779512266.450631      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779512266.967087      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779512266.967127      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779512266.967131      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779512266.967134      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 11338 images belonging to 4 classes.
# Found 2431 images belonging to 4 classes.
# Found 2432 images belonging to 4 classes.
# I0000 00:00:1779512293.437167      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1779512293.443379      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779512310.343412      93 service.cc:152] XLA service 0x7d464814ce40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779512310.343463      93 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779512310.343470      93 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779512312.572371      93 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-05-23 04:58:41.384492: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-23 04:58:41.522210: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1779512333.382620      93 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   3/355 ━━━━━━━━━━━━━━━━━━━━ 2:41 459ms/step - accuracy: 0.2309 - loss: 2.1800
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 270/355 ━━━━━━━━━━━━━━━━━━━━ 1:03 753ms/step - accuracy: 0.5711 - loss: 1.1042
# 2026-05-23 05:02:27.440061: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-23 05:02:27.589910: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-23 05:02:27.726803: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.6004 - loss: 1.0292
# 2026-05-23 05:04:34.928517: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-23 05:04:35.066698: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 379s 964ms/step - accuracy: 0.6007 - loss: 1.0285 - val_accuracy: 0.8326 - val_loss: 0.4564 - learning_rate: 1.0000e-04
# Epoch 2/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 257s 724ms/step - accuracy: 0.8245 - loss: 0.4654 - val_accuracy: 0.8791 - val_loss: 0.3270 - learning_rate: 1.0000e-04
# Epoch 3/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 243s 684ms/step - accuracy: 0.8798 - loss: 0.3374 - val_accuracy: 0.8815 - val_loss: 0.3228 - learning_rate: 1.0000e-04
# Epoch 4/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 238s 671ms/step - accuracy: 0.8978 - loss: 0.2788 - val_accuracy: 0.9050 - val_loss: 0.2834 - learning_rate: 1.0000e-04
# Epoch 5/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 266s 750ms/step - accuracy: 0.9130 - loss: 0.2323 - val_accuracy: 0.9000 - val_loss: 0.2926 - learning_rate: 1.0000e-04
# Epoch 6/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 263s 740ms/step - accuracy: 0.9326 - loss: 0.1902 - val_accuracy: 0.8968 - val_loss: 0.3071 - learning_rate: 1.0000e-04
# Epoch 7/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 252s 711ms/step - accuracy: 0.9348 - loss: 0.1797 - val_accuracy: 0.9091 - val_loss: 0.2627 - learning_rate: 1.0000e-04
# Epoch 8/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 252s 710ms/step - accuracy: 0.9441 - loss: 0.1544 - val_accuracy: 0.8906 - val_loss: 0.3709 - learning_rate: 1.0000e-04
# Epoch 9/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 254s 714ms/step - accuracy: 0.9558 - loss: 0.1364 - val_accuracy: 0.9136 - val_loss: 0.2826 - learning_rate: 1.0000e-04
# Epoch 10/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 651ms/step - accuracy: 0.9541 - loss: 0.1302
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 254s 715ms/step - accuracy: 0.9541 - loss: 0.1302 - val_accuracy: 0.9005 - val_loss: 0.3448 - learning_rate: 1.0000e-04
# Epoch 11/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 261s 733ms/step - accuracy: 0.9643 - loss: 0.0961 - val_accuracy: 0.9276 - val_loss: 0.2496 - learning_rate: 3.0000e-05
# Epoch 12/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 259s 728ms/step - accuracy: 0.9728 - loss: 0.0762 - val_accuracy: 0.9280 - val_loss: 0.2373 - learning_rate: 3.0000e-05
# Epoch 13/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 271s 764ms/step - accuracy: 0.9734 - loss: 0.0672 - val_accuracy: 0.9243 - val_loss: 0.2541 - learning_rate: 3.0000e-05
# Epoch 14/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 271s 764ms/step - accuracy: 0.9755 - loss: 0.0693 - val_accuracy: 0.9264 - val_loss: 0.2605 - learning_rate: 3.0000e-05
# Epoch 15/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 640ms/step - accuracy: 0.9768 - loss: 0.0604
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 249s 701ms/step - accuracy: 0.9768 - loss: 0.0604 - val_accuracy: 0.9231 - val_loss: 0.2793 - learning_rate: 3.0000e-05
# Epoch 16/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 249s 700ms/step - accuracy: 0.9788 - loss: 0.0609 - val_accuracy: 0.9321 - val_loss: 0.2390 - learning_rate: 9.0000e-06
# Epoch 17/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 270s 759ms/step - accuracy: 0.9812 - loss: 0.0531 - val_accuracy: 0.9288 - val_loss: 0.2457 - learning_rate: 9.0000e-06
# Epoch 18/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.9796 - loss: 0.0537
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 270s 759ms/step - accuracy: 0.9796 - loss: 0.0537 - val_accuracy: 0.9255 - val_loss: 0.2470 - learning_rate: 9.0000e-06
# Epoch 19/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 268s 755ms/step - accuracy: 0.9836 - loss: 0.0469 - val_accuracy: 0.9272 - val_loss: 0.2468 - learning_rate: 2.7000e-06
# Epoch 20/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 259s 730ms/step - accuracy: 0.9850 - loss: 0.0437 - val_accuracy: 0.9272 - val_loss: 0.2481 - learning_rate: 2.7000e-06
# Epoch 21/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9872 - loss: 0.0384
# Epoch 21: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 254s 715ms/step - accuracy: 0.9872 - loss: 0.0384 - val_accuracy: 0.9276 - val_loss: 0.2529 - learning_rate: 2.7000e-06
# Epoch 22/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 255s 718ms/step - accuracy: 0.9858 - loss: 0.0404 - val_accuracy: 0.9276 - val_loss: 0.2551 - learning_rate: 8.1000e-07
# Epoch 23/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 255s 720ms/step - accuracy: 0.9851 - loss: 0.0485 - val_accuracy: 0.9272 - val_loss: 0.2521 - learning_rate: 8.1000e-07
# Epoch 24/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.9880 - loss: 0.0377
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 256s 721ms/step - accuracy: 0.9880 - loss: 0.0377 - val_accuracy: 0.9284 - val_loss: 0.2516 - learning_rate: 8.1000e-07
# Epoch 25/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 254s 716ms/step - accuracy: 0.9850 - loss: 0.0434 - val_accuracy: 0.9276 - val_loss: 0.2512 - learning_rate: 2.4300e-07
# Epoch 26/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 261s 735ms/step - accuracy: 0.9839 - loss: 0.0443 - val_accuracy: 0.9272 - val_loss: 0.2497 - learning_rate: 2.4300e-07
# Epoch 27/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.9868 - loss: 0.0401
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.289999643944612e-08.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 258s 727ms/step - accuracy: 0.9867 - loss: 0.0401 - val_accuracy: 0.9251 - val_loss: 0.2522 - learning_rate: 2.4300e-07
# Epoch 28/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 257s 724ms/step - accuracy: 0.9862 - loss: 0.0417 - val_accuracy: 0.9264 - val_loss: 0.2507 - learning_rate: 7.2900e-08
# Epoch 29/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 256s 722ms/step - accuracy: 0.9854 - loss: 0.0440 - val_accuracy: 0.9276 - val_loss: 0.2515 - learning_rate: 7.2900e-08
# Epoch 30/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 646ms/step - accuracy: 0.9853 - loss: 0.0413
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.1869998079182552e-08.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 252s 711ms/step - accuracy: 0.9853 - loss: 0.0413 - val_accuracy: 0.9276 - val_loss: 0.2530 - learning_rate: 7.2900e-08
# Epoch 31/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 257s 725ms/step - accuracy: 0.9859 - loss: 0.0420 - val_accuracy: 0.9276 - val_loss: 0.2492 - learning_rate: 2.1870e-08
# Epoch 32/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 262s 739ms/step - accuracy: 0.9841 - loss: 0.0463 - val_accuracy: 0.9276 - val_loss: 0.2505 - learning_rate: 2.1870e-08
# Epoch 33/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 646ms/step - accuracy: 0.9841 - loss: 0.0491
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.560999210591944e-09.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 253s 712ms/step - accuracy: 0.9841 - loss: 0.0491 - val_accuracy: 0.9264 - val_loss: 0.2521 - learning_rate: 2.1870e-08
# Epoch 34/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 253s 714ms/step - accuracy: 0.9847 - loss: 0.0443 - val_accuracy: 0.9280 - val_loss: 0.2513 - learning_rate: 6.5610e-09
# Epoch 35/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 253s 713ms/step - accuracy: 0.9854 - loss: 0.0428 - val_accuracy: 0.9284 - val_loss: 0.2517 - learning_rate: 6.5610e-09
# Epoch 36/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - accuracy: 0.9847 - loss: 0.0435
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.968299789822936e-09.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 258s 727ms/step - accuracy: 0.9847 - loss: 0.0435 - val_accuracy: 0.9255 - val_loss: 0.2536 - learning_rate: 6.5610e-09
# Epoch 37/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 253s 713ms/step - accuracy: 0.9835 - loss: 0.0464 - val_accuracy: 0.9268 - val_loss: 0.2517 - learning_rate: 1.9683e-09
# Epoch 38/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 252s 709ms/step - accuracy: 0.9836 - loss: 0.0462 - val_accuracy: 0.9276 - val_loss: 0.2525 - learning_rate: 1.9683e-09
# Epoch 39/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.9874 - loss: 0.0376
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.904899236242044e-10.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 255s 719ms/step - accuracy: 0.9874 - loss: 0.0376 - val_accuracy: 0.9276 - val_loss: 0.2508 - learning_rate: 1.9683e-09
# Epoch 40/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 265s 745ms/step - accuracy: 0.9842 - loss: 0.0473 - val_accuracy: 0.9260 - val_loss: 0.2520 - learning_rate: 5.9049e-10
# Epoch 41/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 260s 731ms/step - accuracy: 0.9884 - loss: 0.0373 - val_accuracy: 0.9268 - val_loss: 0.2538 - learning_rate: 5.9049e-10
# Epoch 42/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 656ms/step - accuracy: 0.9865 - loss: 0.0428
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.771469804179304e-10.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 256s 721ms/step - accuracy: 0.9865 - loss: 0.0428 - val_accuracy: 0.9288 - val_loss: 0.2504 - learning_rate: 5.9049e-10
# Epoch 43/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 249s 702ms/step - accuracy: 0.9868 - loss: 0.0400 - val_accuracy: 0.9292 - val_loss: 0.2506 - learning_rate: 1.7715e-10
# Epoch 44/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 249s 702ms/step - accuracy: 0.9843 - loss: 0.0475 - val_accuracy: 0.9272 - val_loss: 0.2510 - learning_rate: 1.7715e-10
# Epoch 45/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 640ms/step - accuracy: 0.9840 - loss: 0.0429
# Epoch 45: ReduceLROnPlateau reducing learning rate to 5.314409329271186e-11.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 250s 703ms/step - accuracy: 0.9840 - loss: 0.0429 - val_accuracy: 0.9284 - val_loss: 0.2503 - learning_rate: 1.7715e-10
# Epoch 46/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 248s 698ms/step - accuracy: 0.9841 - loss: 0.0452 - val_accuracy: 0.9272 - val_loss: 0.2521 - learning_rate: 5.3144e-11
# Epoch 47/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 243s 686ms/step - accuracy: 0.9875 - loss: 0.0373 - val_accuracy: 0.9260 - val_loss: 0.2509 - learning_rate: 5.3144e-11
# Epoch 48/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.9854 - loss: 0.0427
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.5943227987813556e-11.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 241s 680ms/step - accuracy: 0.9854 - loss: 0.0427 - val_accuracy: 0.9260 - val_loss: 0.2528 - learning_rate: 5.3144e-11
# Epoch 49/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 239s 672ms/step - accuracy: 0.9867 - loss: 0.0407 - val_accuracy: 0.9284 - val_loss: 0.2474 - learning_rate: 1.5943e-11
# Epoch 50/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 241s 679ms/step - accuracy: 0.9844 - loss: 0.0483 - val_accuracy: 0.9276 - val_loss: 0.2501 - learning_rate: 1.5943e-11
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 37s 486ms/step - accuracy: 0.9328 - loss: 0.2513
# Test Accuracy: 0.9309210777282715
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 24s 281ms/step
#               precision    recall  f1-score   support
#
#        glass       0.95      0.92      0.94       627
#        metal       0.90      0.95      0.93       569
#        paper       0.96      0.94      0.95       599
#      plastic       0.91      0.91      0.91       637
#
#     accuracy                           0.93      2432
#    macro avg       0.93      0.93      0.93      2432
# weighted avg       0.93      0.93      0.93      2432

# %%
model.save("garbage_classifier_MobileNet.keras")

import json
with open("class_indices.json", "w") as f:
    json.dump(train_generator.class_indices, f)

print("Đã lưu model và class_indices!")
# Out:
# Đã lưu model và class_indices!
