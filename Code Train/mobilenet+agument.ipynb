# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

train_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/train"
val_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/val"
test_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/test"


train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,

    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,

    zoom_range=0.2,

    shear_range=0.2,

    horizontal_flip=True,

    brightness_range=[0.8, 1.2]
)


val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

base_model = MobileNet(
    include_top=False,
    weights='imagenet',
    input_shape=(224,224,3)
)

for layer in base_model.layers:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)

output = Dense(
    train_generator.num_classes,
    activation='softmax'
)(x)

model = Model(
    inputs=base_model.input,
    outputs=output
)

model.compile(
    optimizer=Adam(1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# early_stop = EarlyStopping(
#     monitor='val_loss',
#     patience=5,
#     restore_best_weights=True
# )

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    verbose=1
)

history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[reduce_lr]
)


loss, acc = model.evaluate(test_generator)

print("Test Accuracy:", acc)

y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(
    test_generator.classes,
    y_pred_classes
)

plt.figure(figsize=(10,8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=train_generator.class_indices.keys(),
    yticklabels=train_generator.class_indices.keys()
)

plt.show()

print(classification_report(
    test_generator.classes,
    y_pred_classes,
    target_names=list(train_generator.class_indices.keys())
))
# Out:
# 2026-05-23 04:55:45.556995: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779512145.759206      22 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779512145.818662      22 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779512146.307665      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779512146.307717      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779512146.307720      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779512146.307723      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 11338 images belonging to 4 classes.
# Found 2431 images belonging to 4 classes.
# Found 2432 images belonging to 4 classes.
# I0000 00:00:1779512177.277222      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1779512177.283667      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779512196.700830      92 service.cc:152] XLA service 0x78f5500034b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779512196.700879      92 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779512196.700885      92 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779512199.190559      92 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-05-23 04:56:49.066487: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-23 04:56:49.205398: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1779512222.841904      92 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  31/355 ━━━━━━━━━━━━━━━━━━━━ 3:34 662ms/step - accuracy: 0.3089 - loss: 1.8128
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 273/355 ━━━━━━━━━━━━━━━━━━━━ 56s 694ms/step - accuracy: 0.5610 - loss: 1.1128
# 2026-05-23 05:00:23.993885: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-23 05:00:24.133426: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.5910 - loss: 1.0371
# 2026-05-23 05:02:07.991314: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-23 05:02:08.130514: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-23 05:02:08.270011: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-23 05:02:08.409026: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 349s 861ms/step - accuracy: 0.5913 - loss: 1.0363 - val_accuracy: 0.8396 - val_loss: 0.4221 - learning_rate: 1.0000e-04
# Epoch 2/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 225s 632ms/step - accuracy: 0.8320 - loss: 0.4514 - val_accuracy: 0.8807 - val_loss: 0.3453 - learning_rate: 1.0000e-04
# Epoch 3/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 229s 646ms/step - accuracy: 0.8761 - loss: 0.3358 - val_accuracy: 0.8898 - val_loss: 0.3148 - learning_rate: 1.0000e-04
# Epoch 4/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 231s 651ms/step - accuracy: 0.8978 - loss: 0.2794 - val_accuracy: 0.8930 - val_loss: 0.2986 - learning_rate: 1.0000e-04
# Epoch 5/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 233s 655ms/step - accuracy: 0.9227 - loss: 0.2125 - val_accuracy: 0.9050 - val_loss: 0.2782 - learning_rate: 1.0000e-04
# Epoch 6/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 231s 650ms/step - accuracy: 0.9329 - loss: 0.1908 - val_accuracy: 0.9054 - val_loss: 0.2684 - learning_rate: 1.0000e-04
# Epoch 7/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 230s 647ms/step - accuracy: 0.9394 - loss: 0.1745 - val_accuracy: 0.9054 - val_loss: 0.3103 - learning_rate: 1.0000e-04
# Epoch 8/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 229s 644ms/step - accuracy: 0.9448 - loss: 0.1535 - val_accuracy: 0.9116 - val_loss: 0.2889 - learning_rate: 1.0000e-04
# Epoch 9/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9548 - loss: 0.1304
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 229s 645ms/step - accuracy: 0.9548 - loss: 0.1304 - val_accuracy: 0.9009 - val_loss: 0.3573 - learning_rate: 1.0000e-04
# Epoch 10/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 230s 647ms/step - accuracy: 0.9603 - loss: 0.1135 - val_accuracy: 0.9198 - val_loss: 0.2349 - learning_rate: 3.0000e-05
# Epoch 11/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 232s 652ms/step - accuracy: 0.9719 - loss: 0.0835 - val_accuracy: 0.9231 - val_loss: 0.2458 - learning_rate: 3.0000e-05
# Epoch 12/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 228s 643ms/step - accuracy: 0.9752 - loss: 0.0747 - val_accuracy: 0.9227 - val_loss: 0.2554 - learning_rate: 3.0000e-05
# Epoch 13/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9759 - loss: 0.0683
# Epoch 13: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 228s 643ms/step - accuracy: 0.9759 - loss: 0.0683 - val_accuracy: 0.9292 - val_loss: 0.2363 - learning_rate: 3.0000e-05
# Epoch 14/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 228s 643ms/step - accuracy: 0.9782 - loss: 0.0626 - val_accuracy: 0.9321 - val_loss: 0.2271 - learning_rate: 9.0000e-06
# Epoch 15/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 223s 629ms/step - accuracy: 0.9826 - loss: 0.0527 - val_accuracy: 0.9317 - val_loss: 0.2399 - learning_rate: 9.0000e-06
# Epoch 16/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 220s 619ms/step - accuracy: 0.9810 - loss: 0.0519 - val_accuracy: 0.9338 - val_loss: 0.2360 - learning_rate: 9.0000e-06
# Epoch 17/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.9813 - loss: 0.0540
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 217s 612ms/step - accuracy: 0.9813 - loss: 0.0540 - val_accuracy: 0.9321 - val_loss: 0.2455 - learning_rate: 9.0000e-06
# Epoch 18/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 221s 624ms/step - accuracy: 0.9864 - loss: 0.0432 - val_accuracy: 0.9334 - val_loss: 0.2458 - learning_rate: 2.7000e-06
# Epoch 19/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 237s 668ms/step - accuracy: 0.9843 - loss: 0.0477 - val_accuracy: 0.9329 - val_loss: 0.2431 - learning_rate: 2.7000e-06
# Epoch 20/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.9823 - loss: 0.0492
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 233s 656ms/step - accuracy: 0.9823 - loss: 0.0492 - val_accuracy: 0.9329 - val_loss: 0.2462 - learning_rate: 2.7000e-06
# Epoch 21/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 233s 656ms/step - accuracy: 0.9812 - loss: 0.0521 - val_accuracy: 0.9321 - val_loss: 0.2451 - learning_rate: 8.1000e-07
# Epoch 22/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 235s 663ms/step - accuracy: 0.9848 - loss: 0.0469 - val_accuracy: 0.9334 - val_loss: 0.2451 - learning_rate: 8.1000e-07
# Epoch 23/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 0.9830 - loss: 0.0476
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# 355/355 ━━━━━━━━━━━━━━━━━━━━
50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 233s 656ms/step - accuracy: 0.9871 - loss: 0.0423 - val_accuracy: 0.9334 - val_loss: 0.2441 - learning_rate: 5.9049e-10
# Epoch 40/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 229s 643ms/step - accuracy: 0.9840 - loss: 0.0478 - val_accuracy: 0.9350 - val_loss: 0.2423 - learning_rate: 5.9049e-10
# Epoch 41/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.9867 - loss: 0.0426
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.771469804179304e-10.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 235s 662ms/step - accuracy: 0.9867 - loss: 0.0426 - val_accuracy: 0.9334 - val_loss: 0.2453 - learning_rate: 5.9049e-10
# Epoch 42/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 238s 671ms/step - accuracy: 0.9849 - loss: 0.0466 - val_accuracy: 0.9329 - val_loss: 0.2459 - learning_rate: 1.7715e-10
# Epoch 43/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 233s 657ms/step - accuracy: 0.9825 - loss: 0.0450 - val_accuracy: 0.9329 - val_loss: 0.2450 - learning_rate: 1.7715e-10
# Epoch 44/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.9848 - loss: 0.0439
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.314409329271186e-11.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 233s 655ms/step - accuracy: 0.9849 - loss: 0.0439 - val_accuracy: 0.9334 - val_loss: 0.2455 - learning_rate: 1.7715e-10
# Epoch 45/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 235s 661ms/step - accuracy: 0.9816 - loss: 0.0502 - val_accuracy: 0.9338 - val_loss: 0.2448 - learning_rate: 5.3144e-11
# Epoch 46/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 228s 642ms/step - accuracy: 0.9840 - loss: 0.0459 - val_accuracy: 0.9342 - val_loss: 0.2447 - learning_rate: 5.3144e-11
# Epoch 47/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.9845 - loss: 0.0453
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.5943227987813556e-11.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 229s 644ms/step - accuracy: 0.9845 - loss: 0.0453 - val_accuracy: 0.9338 - val_loss: 0.2458 - learning_rate: 5.3144e-11
# Epoch 48/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 230s 646ms/step - accuracy: 0.9865 - loss: 0.0412 - val_accuracy: 0.9338 - val_loss: 0.2445 - learning_rate: 1.5943e-11
# Epoch 49/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 235s 663ms/step - accuracy: 0.9844 - loss: 0.0448 - val_accuracy: 0.9334 - val_loss: 0.2454 - learning_rate: 1.5943e-11
# Epoch 50/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.9833 - loss: 0.0502
# Epoch 50: ReduceLROnPlateau reducing learning rate to 4.782968292260659e-12.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 236s 665ms/step - accuracy: 0.9833 - loss: 0.0502 - val_accuracy: 0.9334 - val_loss: 0.2446 - learning_rate: 1.5943e-11
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 33s 444ms/step - accuracy: 0.9325 - loss: 0.2575
# Test Accuracy: 0.9300987124443054
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 22s 244ms/step
#               precision    recall  f1-score   support
#
#        glass       0.95      0.93      0.94       627
#        metal       0.92      0.94      0.93       569
#        paper       0.96      0.94      0.95       599
#      plastic       0.90      0.91      0.90       637
#
#     accuracy                           0.93      2432
#    macro avg       0.93      0.93      0.93      2432
# weighted avg       0.93      0.93      0.93      2432

# %%
model.save("garbage_classifier_MobileNet.keras")

import json
with open("class_indices.json", "w") as f:
    json.dump(train_generator.class_indices, f)

print("Đã lưu model và class_indices!")
# Out:
# Đã lưu model và class_indices!
