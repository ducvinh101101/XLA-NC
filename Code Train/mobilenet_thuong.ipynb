# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

train_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/train"
val_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/val"
test_dir = "/kaggle/input/notebooks/ducvenh/split-merge-garbage/test"


train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

base_model = MobileNet(
    include_top=False,
    weights='imagenet',
    input_shape=(224,224,3)
)

for layer in base_model.layers:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)

output = Dense(
    train_generator.num_classes,
    activation='softmax'
)(x)

model = Model(
    inputs=base_model.input,
    outputs=output
)

model.compile(
    optimizer=Adam(1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# early_stop = EarlyStopping(
#     monitor='val_loss',
#     patience=5,
#     restore_best_weights=True
# )

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    verbose=1
)

history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[reduce_lr]
)


loss, acc = model.evaluate(test_generator)

print("Test Accuracy:", acc)

y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(
    test_generator.classes,
    y_pred_classes
)

plt.figure(figsize=(10,8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=train_generator.class_indices.keys(),
    yticklabels=train_generator.class_indices.keys()
)

plt.show()

print(classification_report(
    test_generator.classes,
    y_pred_classes,
    target_names=list(train_generator.class_indices.keys())
))
# Out:
# 2026-05-22 01:21:18.636111: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779412878.865735      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779412878.936044      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779412879.484193      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779412879.484235      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779412879.484238      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779412879.484241      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 11338 images belonging to 4 classes.
# Found 2431 images belonging to 4 classes.
# Found 2432 images belonging to 4 classes.
# I0000 00:00:1779412911.237770      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1779412911.243717      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779412927.440500      90 service.cc:152] XLA service 0x7eaeec14a180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779412927.440535      90 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779412927.440539      90 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779412929.679913      90 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-05-22 01:22:18.905256: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-22 01:22:19.044057: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-22 01:22:19.182393: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1779412951.405445      90 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  42/355 ━━━━━━━━━━━━━━━━━━━━ 2:07 408ms/step - accuracy: 0.4306 - loss: 1.5665
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 136/355 ━━━━━━━━━━━━━━━━━━━━ 1:31 416ms/step - accuracy: 0.5485 - loss: 1.1971
# 2026-05-22 01:23:38.899328: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-22 01:23:39.050439: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.6537 - loss: 0.9171
# 2026-05-22 01:25:59.584016: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-22 01:25:59.725336: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-22 01:25:59.863685: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-22 01:26:00.001851: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 247s 587ms/step - accuracy: 0.6540 - loss: 0.9164 - val_accuracy: 0.8774 - val_loss: 0.3324 - learning_rate: 1.0000e-04
# Epoch 2/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 88s 245ms/step - accuracy: 0.8966 - loss: 0.2859 - val_accuracy: 0.8926 - val_loss: 0.2920 - learning_rate: 1.0000e-04
# Epoch 3/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 87s 245ms/step - accuracy: 0.9459 - loss: 0.1590 - val_accuracy: 0.9066 - val_loss: 0.2826 - learning_rate: 1.0000e-04
# Epoch 4/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 87s 246ms/step - accuracy: 0.9719 - loss: 0.0812 - val_accuracy: 0.9054 - val_loss: 0.2950 - learning_rate: 1.0000e-04
# Epoch 5/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 86s 241ms/step - accuracy: 0.9795 - loss: 0.0599 - val_accuracy: 0.9005 - val_loss: 0.3403 - learning_rate: 1.0000e-04
# Epoch 6/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.
50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 86s 242ms/step - accuracy: 0.9983 - loss: 0.0055 - val_accuracy: 0.9227 - val_loss: 0.3013 - learning_rate: 1.7715e-10
# Epoch 40/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9996 - loss: 0.0038
# Epoch 40: ReduceLROnPlateau reducing learning rate to 5.314409329271186e-11.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 85s 238ms/step - accuracy: 0.9996 - loss: 0.0038 - val_accuracy: 0.9227 - val_loss: 0.3002 - learning_rate: 1.7715e-10
# Epoch 41/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 85s 240ms/step - accuracy: 0.9981 - loss: 0.0070 - val_accuracy: 0.9223 - val_loss: 0.3008 - learning_rate: 5.3144e-11
# Epoch 42/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 84s 236ms/step - accuracy: 0.9991 - loss: 0.0043 - val_accuracy: 0.9227 - val_loss: 0.3017 - learning_rate: 5.3144e-11
# Epoch 43/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9992 - loss: 0.0041
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.5943227987813556e-11.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 87s 244ms/step - accuracy: 0.9992 - loss: 0.0041 - val_accuracy: 0.9223 - val_loss: 0.2999 - learning_rate: 5.3144e-11
# Epoch 44/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 83s 234ms/step - accuracy: 0.9979 - loss: 0.0065 - val_accuracy: 0.9227 - val_loss: 0.3008 - learning_rate: 1.5943e-11
# Epoch 45/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 91s 257ms/step - accuracy: 0.9993 - loss: 0.0050 - val_accuracy: 0.9231 - val_loss: 0.2987 - learning_rate: 1.5943e-11
# Epoch 46/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9982 - loss: 0.0067
# Epoch 46: ReduceLROnPlateau reducing learning rate to 4.782968292260659e-12.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 93s 261ms/step - accuracy: 0.9982 - loss: 0.0067 - val_accuracy: 0.9231 - val_loss: 0.3009 - learning_rate: 1.5943e-11
# Epoch 47/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 90s 253ms/step - accuracy: 0.9984 - loss: 0.0064 - val_accuracy: 0.9235 - val_loss: 0.2986 - learning_rate: 4.7830e-12
# Epoch 48/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 90s 252ms/step - accuracy: 0.9985 - loss: 0.0051 - val_accuracy: 0.9227 - val_loss: 0.3008 - learning_rate: 4.7830e-12
# Epoch 49/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9994 - loss: 0.0037
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.4348904876781975e-12.
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 89s 249ms/step - accuracy: 0.9994 - loss: 0.0037 - val_accuracy: 0.9227 - val_loss: 0.3018 - learning_rate: 4.7830e-12
# Epoch 50/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 87s 245ms/step - accuracy: 0.9993 - loss: 0.0044 - val_accuracy: 0.9235 - val_loss: 0.2986 - learning_rate: 1.4349e-12
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 35s 464ms/step - accuracy: 0.9226 - loss: 0.2879
# Test Accuracy: 0.9268091917037964
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 19s 222ms/step
#               precision    recall  f1-score   support
#
#        glass       0.96      0.91      0.93       627
#        metal       0.91      0.93      0.92       569
#        paper       0.95      0.96      0.95       599
#      plastic       0.90      0.91      0.91       637
#
#     accuracy                           0.93      2432
#    macro avg       0.93      0.93      0.93      2432
# weighted avg       0.93      0.93      0.93      2432

# %%
model.save("garbage_classifier_MobileNet.keras")

import json
with open("class_indices.json", "w") as f:
    json.dump(train_generator.class_indices, f)

print("Đã lưu model và class_indices!")
# Out:
# Đã lưu model và class_indices!
